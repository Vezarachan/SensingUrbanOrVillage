# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
base_path = 'D:/Research/datasets/UrbanOrRural/Datasets-Compressed/'

# %%
files = os.listdir(base_path)

# %%
len(files)
# Out:
# 95518

# %%
m = folium.Map(location=(48.153066, 11.547221), zoom_start=12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
with open('./Datasets/SamplePoints/samples.csv', 'a') as f:
    for file in files:
        file_name = file.replace('.jpg', '')
        print(file_name)
        _, x, y = file_name.split(',')
        f.write(f'{x},{y}\n')
# Out:
# 1000037054407965,11.39443634,48.14419774
# 1000056633734108,11.44217078,48.20371525
# 1000084560677852,11.744363,48.14301
# 1000169507932515,11.403894,48.126778
# 1000179054561431,11.449047,48.104329
# 1000216893849237,11.510212,48.04729
# 1000239990785146,11.51019214,48.22773526
# 1000252437176754,11.5012,48.118255
# 1000288527175954,11.523564,48.078706
# 1000317407213992,11.60919769,48.09251415
# 1000321610372173,11.458413,48.197079
# 1000336477167719,11.501264,48.131049
# 1000348247370450,11.64747116,48.17747547
# 1000380910725895,11.57566774,48.16838255
# 1000381234039960,11.3640996,48.20051321
# 1000398190662416,11.713647,48.065243
# 1000428287967893,11.42835195,48.13737342
# 1000430783694443,11.621046,48.161416
# 1000483150952322,11.742668,48.165484
# 1000489820488610,11.622865,48.140776
# 1000538071263540,11.42208,48.120436
# 1000546991025506,11.46621617,48.13843776
# 1000555240964758,11.75626235,48.14247378
# 1000559273836940,11.49990072,48.18706493
# ...

# %%
from itertools import batched

# %%
a = np.arange(95000)

# %%
b = list(batched(a, 1024))

# %%
len(b)
# Out:
# 93
